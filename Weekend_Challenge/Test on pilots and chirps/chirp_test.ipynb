# %% [markdown]
# # Chirp test
# I test chirp to see how they behave by doing correlation to find starting time and from the received signal, I compared it using different graphs such as spectrogram, PSD, Rough relative response at different frequencies.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sounddevice as sd

from scipy.io.wavfile import write
from scipy.signal import chirp, welch, spectrogram, correlate, correlation_lags
from scipy.signal.windows import tukey


print("sounddevice imported successfully")
print(sd.query_devices())
# Out:
# sounddevice imported successfully
#    0 Microsoft 声音映射器 - Input, MME (2 in, 0 out)
# >  1 麦克风阵列 (适用于数字麦克风的英特尔® 智音技术), MME (6 in, 0 out)
#    2 Microsoft 声音映射器 - Output, MME (0 in, 2 out)
# <  3 扬声器 (Realtek(R) Audio), MME (0 in, 2 out)
#    4 主声音捕获驱动程序, Windows DirectSound (2 in, 0 out)
#    5 麦克风阵列 (适用于数字麦克风的英特尔® 智音技术), Windows DirectSound (6 in, 0 out)
#    6 主声音驱动程序, Windows DirectSound (0 in, 2 out)
#    7 扬声器 (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#    8 扬声器 (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#    9 麦克风阵列 (适用于数字麦克风的英特尔® 智音技术), Windows WASAPI (4 in, 0 out)
#   10 立体声混音 (Realtek HD Audio Stereo input), Windows WDM-KS (2 in, 0 out)
#   11 Headphones 1 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   12 Headphones 2 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (0 in, 2 out)
#   13 电脑扬声器 (Realtek HD Audio 2nd output with SST), Windows WDM-KS (2 in, 0 out)
# ...

# %%
fs = 48000
T_chirp = 1.0
f0 = 2000
f1 = 16000
amp = 0.5

t = np.arange(int(T_chirp * fs)) / fs

up_chirp = chirp(t, f0=f0, f1=f1, t1=T_chirp, method="linear")
down_chirp = chirp(t, f0=f1, f1=f0, t1=T_chirp, method="linear")

alpha = 0.1  # fraction of signal used for tapering
window = tukey(len(t), alpha=alpha)

up_chirp = amp * up_chirp * window
down_chirp = amp * down_chirp * window

silence_1s = np.zeros(int(1.0 * fs))
silence_02s = np.zeros(int(0.2 * fs))

tx = np.concatenate([
    silence_1s,
    up_chirp,
    silence_02s,
    down_chirp,
    silence_1s
])

write("chirp_test_dual_tx.wav", fs, tx.astype(np.float32))

print("Saved chirp_test_tx.wav")
print("Duration:", len(tx) / fs, "seconds")
# Out:
# Saved chirp_test_tx.wav
# Duration: 4.2 seconds

# %%
time_tx = np.arange(len(tx)) / fs

plt.figure(figsize=(12, 4))
plt.plot(time_tx, tx)
plt.xlabel("Time / s")
plt.ylabel("Amplitude")
plt.title("Transmitted Chirp Test Signal")
plt.grid(True)
plt.show()

# %%
# Out:
# Recording started.
# Play chirp_test_tx.wav now.
# Recording finished.
# Saved chirp_test_rx.wav
# Max amplitude: 0.16903687
# Duration: 5.0 seconds

# %%
# match filter
from scipy.signal import chirp, correlate, correlation_lags

T_chirp = 0.5
f0 = 500
f1 = 22000
amp = 1.0

def generate_reference_chirps(fs, T_chirp=0.5, f0=500, f1=8000, amp=0.3):
    t = np.arange(int(T_chirp * fs)) / fs

    up = chirp(t, f0=f0, f1=f1, t1=T_chirp, method="linear")
    down = chirp(t, f0=f1, f1=f0, t1=T_chirp, method="linear")

    window = np.hanning(len(t))
    up = amp * up * window
    down = amp * down * window

    return up, down

up_ref, down_ref = generate_reference_chirps(fs_rx, T_chirp, f0, f1, amp)

rx_proc = rx - np.mean(rx)
rx_proc = rx_proc / (np.max(np.abs(rx_proc)) + 1e-12)

corr_up = correlate(rx_proc, up_ref, mode="full")
lags_up = correlation_lags(len(rx_proc), len(up_ref), mode="full")
mag_up = np.abs(corr_up)

corr_down = correlate(rx_proc, down_ref, mode="full")
lags_down = correlation_lags(len(rx_proc), len(down_ref), mode="full")
mag_down = np.abs(corr_down)

peak_lag_up = lags_up[np.argmax(mag_up)]
peak_time_up = peak_lag_up / fs_rx

peak_lag_down = lags_down[np.argmax(mag_down)]
peak_time_down = peak_lag_down / fs_rx

print("Up-chirp detected time:", peak_time_up)
print("Down-chirp detected time:", peak_time_down)
print("Detected spacing:", peak_time_down - peak_time_up)
print("Expected spacing:", T_chirp + 0.2)

plt.figure(figsize=(12, 4))
plt.plot(lags_up / fs_rx, mag_up, label="up-chirp matched filter")
plt.plot(lags_down / fs_rx, mag_down, label="down-chirp matched filter")
plt.axvline(peak_time_up, linestyle="--", label="up peak")
plt.axvline(peak_time_down, linestyle="--", label="down peak")
plt.xlabel("Lag / s")
plt.ylabel("Matched filter magnitude")
plt.title("Matched Filter Output")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Up-chirp detected time: 2.4760416666666667
# Down-chirp detected time: 2.762125
# Detected spacing: 0.28608333333333347
# Expected spacing: 0.7

# %% [markdown]
# The chirp receiver test successfully detected both the up-chirp and down-chirp using matched filtering. The detected time separation between the two chirps was 0.69998 s, compared with the expected 0.70000 s, corresponding to an error of approximately one sample at 48 kHz. This confirms that the receiver can reliably detect the chirp preamble and estimate timing with sample-level accuracy under the tested acoustic setup

# %%
# Analyze echoes around the up-chirp peak
pre_ms = 10
post_ms = 100

pre_samples = int(pre_ms / 1000 * fs_rx)
post_samples = int(post_ms / 1000 * fs_rx)

mask = (lags_up >= peak_lag_up - pre_samples) & (lags_up <= peak_lag_up + post_samples)

relative_time_ms = (lags_up[mask] - peak_lag_up) / fs_rx * 1000
echo_mag = mag_up[mask]
echo_mag_norm = echo_mag / (np.max(echo_mag) + 1e-12)
echo_mag_db = 20 * np.log10(echo_mag_norm + 1e-12)

plt.figure(figsize=(12, 4))
plt.plot(relative_time_ms, echo_mag_db)
plt.axvline(0, linestyle="--", label="Main peak")
plt.ylim(-60, 5)
plt.xlabel("Delay relative to main peak / ms")
plt.ylabel("Relative level / dB")
plt.title("Echo Profile in dB")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Analyze echoes around the down-chirp peak
mask = (lags_down >= peak_lag_down - pre_samples) & (lags_down <= peak_lag_down + post_samples)

relative_time_ms = (lags_down[mask] - peak_lag_down) / fs_rx * 1000
echo_mag = mag_down[mask]
echo_mag_norm = echo_mag / (np.max(echo_mag) + 1e-12)
echo_mag_db = 20 * np.log10(echo_mag_norm + 1e-12)

plt.figure(figsize=(12, 4))
plt.plot(relative_time_ms, echo_mag_db)
plt.axvline(0, linestyle="--", label="Main peak")
plt.ylim(-60, 5)
plt.xlabel("Delay relative to main peak / ms")
plt.ylabel("Relative level / dB")
plt.title("Echo Profile in dB")
plt.legend()
plt.grid(True)

# %% [markdown]
# For my room, the matched filter successfully detected main peak, but echo is relatively strong. The echo profile shows a clear main peak at 0 ms, corresponding to the direct acoustic path. Several early reflections are visible within the first 5 ms and remain relatively strong, around -10 to -20 dB. Additional multipath components extend up to around 30–40 ms, after which the response gradually decays towards the noise floor. This indicates a moderately reverberant acoustic channel, where early reflections may affect synchronisation and OFDM demodulation unless the cyclic prefix or equalisation is sufficiently robust.

# %%
def crop_segment(x, fs, start_time, duration):
    start = int(start_time * fs)
    end = int((start_time + duration) * fs)
    start = max(start, 0)
    end = min(end, len(x))
    return x[start:end]

# Use processed recording
rx_proc = rx - np.mean(rx)
rx_proc = rx_proc / (np.max(np.abs(rx_proc)) + 1e-12)

up_rx = crop_segment(rx_proc, fs_rx, peak_time_up, T_chirp)
down_rx = crop_segment(rx_proc, fs_rx, peak_time_down, T_chirp)

# Noise segment before up-chirp, for example 0.5 s before the detected up-chirp
noise_rx = crop_segment(rx_proc, fs_rx, max(0, peak_time_up - 0.7), 0.5)

print("up segment duration:", len(up_rx) / fs_rx)
print("down segment duration:", len(down_rx) / fs_rx)
print("noise segment duration:", len(noise_rx) / fs_rx)
# Out:
# up segment duration: 0.5
# down segment duration: 0.5
# noise segment duration: 0.49997916666666664

# %%
from scipy.signal import welch
import numpy as np
import matplotlib.pyplot as plt

def compute_psd_db(x, fs, nperseg=4096):
    nperseg = min(nperseg, len(x))
    f, Pxx = welch(
        x,
        fs=fs,
        window="hann",
        nperseg=nperseg,
        noverlap=nperseg // 2,
        scaling="density"
    )
    Pxx_dB = 10 * np.log10(Pxx + 1e-12)
    return f, Pxx_dB, Pxx

f_up, up_db, up_Pxx = compute_psd_db(up_rx, fs_rx)
f_down, down_db, down_Pxx = compute_psd_db(down_rx, fs_rx)
f_noise, noise_db, noise_Pxx = compute_psd_db(noise_rx, fs_rx)

plt.figure(figsize=(12, 5))
plt.plot(f_up, up_db, label="Recorded up-chirp")
plt.plot(f_down, down_db, label="Recorded down-chirp")
plt.plot(f_noise, noise_db, label="Background noise")
plt.xlim(0, 10000)
plt.xlabel("Frequency / Hz")
plt.ylabel("PSD / dB/Hz")
plt.title("PSD Comparison: Up-chirp, Down-chirp, Noise")
plt.legend()
plt.grid(True)
plt.show()

# %%
def band_power(f, Pxx, f_low, f_high):
    mask = (f >= f_low) & (f <= f_high)
    return np.trapezoid(Pxx[mask], f[mask])

f_low = 500
f_high = 8000

up_band_power = band_power(f_up, up_Pxx, f_low, f_high)
down_band_power = band_power(f_down, down_Pxx, f_low, f_high)
noise_band_power = band_power(f_noise, noise_Pxx, f_low, f_high)

up_snr_db = 10 * np.log10(up_band_power / (noise_band_power + 1e-12))
down_snr_db = 10 * np.log10(down_band_power / (noise_band_power + 1e-12))

print("Up-chirp band power:", up_band_power)
print("Down-chirp band power:", down_band_power)
print("Noise band power:", noise_band_power)
print("Up-chirp band SNR:", up_snr_db, "dB")
print("Down-chirp band SNR:", down_snr_db, "dB")
# Out:
# Up-chirp band power: 0.06119474736165638
# Down-chirp band power: 0.042635387595948024
# Noise band power: 2.4039063206711652e-06
# Up-chirp band SNR: 44.05796426140157 dB
# Down-chirp band SNR: 42.48852495455226 dB

# %%
bands = [
    (500, 1000),
    (1000, 2000),
    (2000, 4000),
    (4000, 6000),
    (6000, 8000)
]

print("Band power comparison:")
for low, high in bands:
    up_bp = band_power(f_up, up_Pxx, low, high)
    down_bp = band_power(f_down, down_Pxx, low, high)
    noise_bp = band_power(f_noise, noise_Pxx, low, high)

    up_snr = 10 * np.log10(up_bp / (noise_bp + 1e-12))
    down_snr = 10 * np.log10(down_bp / (noise_bp + 1e-12))

    print(f"{low}-{high} Hz:")
    print(f"  up SNR   = {up_snr:.2f} dB")
    print(f"  down SNR = {down_snr:.2f} dB")
# Out:
# Band power comparison:
# 500-1000 Hz:
#   up SNR   = 6.46 dB
#   down SNR = -0.31 dB
# 1000-2000 Hz:
#   up SNR   = 32.50 dB
#   down SNR = 26.66 dB
# 2000-4000 Hz:
#   up SNR   = 50.86 dB
#   down SNR = 47.48 dB
# 4000-6000 Hz:
#   up SNR   = 48.82 dB
#   down SNR = 49.83 dB
# 6000-8000 Hz:
#   up SNR   = 44.64 dB
#   down SNR = 45.98 dB

# %%
# Generate reference up chirp
from scipy.signal import chirp

t_ref = np.arange(int(T_chirp * fs_rx)) / fs_rx
up_ref = chirp(t_ref, f0=500, f1=8000, t1=T_chirp, method="linear")
up_ref = up_ref * np.hanning(len(up_ref))

f_ref, ref_db, ref_Pxx = compute_psd_db(up_ref, fs_rx)

# Interpolate reference PSD onto recorded frequency axis
ref_db_interp = np.interp(f_up, f_ref, ref_db)

# Rough channel response estimate
H_db = up_db - ref_db_interp

# Remove arbitrary offset by normalising around 1–2 kHz
norm_mask = (f_up >= 1000) & (f_up <= 2000)
H_db_norm = H_db - np.mean(H_db[norm_mask])

plt.figure(figsize=(12, 5))
plt.plot(f_up, H_db_norm)
plt.xlim(500, 8000)
plt.xlabel("Frequency / Hz")
plt.ylabel("Relative response / dB")
plt.title("Rough Receiver Frequency Response from Up-Chirp")
plt.grid(True)
plt.show()

# %% [markdown]
# The graph here is a relative normalised chirp response. As hanning window is used at two ends, this causing some artefacts at two ends. At freq around 1k to 7kHz, we can see responses of some frequencies are much better than some extremly bad one. This may because echo cancellation and enhancement and also because reference response is small compared to these frequency.

# %% [markdown]
# # Chirp test on various parameters
# I have investigated different chirp methods and their performances in LR5.

# %%
# Generate chirps
def generate_chirp(fs, T_chirp=1.0, f0=500, f1=22000, amp=0.5, method="linear",filename="chirp_test_all_freq_tx.wav"):
    t = np.arange(int(T_chirp * fs)) / fs

    up_chirp = chirp(t, f0=f0, f1=f1, t1=T_chirp, method=method)

    alpha = 0.1  # fraction of signal used for tapering
    window = tukey(len(t), alpha=alpha)

    up_chirp = amp * up_chirp * window

    silence_1s = np.zeros(int(1.0 * fs))

    tx = np.concatenate([
        silence_1s,
        up_chirp,
        silence_1s
    ])

    write(filename, fs, tx.astype(np.float32))

    print("Saved", filename)
    print("Duration:", len(tx) / fs, "seconds")
    return up_chirp

def record_chirp_response(fs_rx = 48000, record_seconds = 5.0, filename = "chirp_test_rx.wav"):
    print("Recording started.")
    print("Play chirp_test_tx.wav now.")

    rx = sd.rec(
        int(record_seconds * fs_rx),
        samplerate=fs_rx,
        channels=1,
        dtype="float32"
    )

    sd.wait()

    rx = rx[:, 0]

    write(filename, fs_rx, rx.astype(np.float32))

    print("Recording finished.")
    print("Saved", filename)
    print("Max amplitude:", np.max(np.abs(rx)))
    print("Duration:", len(rx) / fs_rx, "seconds")

# read recorded signal
from scipy.io import wavfile
def read_recorded_signal(filename="chirp_test_rx.wav"):
    fs_rx, rx = wavfile.read(filename)
    rx = rx.astype(np.float32)
    return fs_rx, rx

def plot_recorded_signal(rx, fs_rx):
    time_rx = np.arange(len(rx)) / fs_rx

    plt.figure(figsize=(12, 4))
    plt.plot(time_rx, rx)
    plt.xlabel("Time / s")
    plt.ylabel("Amplitude")
    plt.title("Recorded Signal")
    plt.grid(True)
    plt.show()

def spectrogram_analysis_no_smoothing(rx, fs_rx):
    rx_proc = rx - np.mean(rx)
    rx_proc = rx_proc / (np.max(np.abs(rx_proc)) + 1e-12)

    f_spec, t_spec, Sxx = spectrogram(
        rx_proc,
        fs=fs_rx,
        window="boxcar",      # no tapering window
        nperseg=1024,
        noverlap=0,           # no overlap
        detrend=False,        # no per-segment detrending
        scaling="density",
        mode="psd"
    )

    Sxx_dB = 10 * np.log10(Sxx + 1e-12)

    plt.figure(figsize=(12, 5))
    plt.pcolormesh(t_spec, f_spec, Sxx_dB, shading="nearest")
    plt.ylim(0, 10000)
    plt.xlabel("Time / s")
    plt.ylabel("Frequency / Hz")
    plt.title("Spectrogram of Recorded Signal, No Extra Smoothing")
    plt.colorbar(label="Power / dB")
    plt.show()

def spectrogram_analysis(rx, fs_rx):
    rx_proc = rx - np.mean(rx)
    rx_proc = rx_proc / (np.max(np.abs(rx_proc)) + 1e-12)

    f_spec, t_spec, Sxx = spectrogram(
        rx_proc,
        fs=fs_rx,
        nperseg=1024,
        noverlap=768
    )

    Sxx_dB = 10 * np.log10(Sxx + 1e-12)

    plt.figure(figsize=(12, 5))
    plt.pcolormesh(t_spec, f_spec, Sxx_dB, shading="gouraud")
    plt.ylim(0, 10000)
    plt.xlabel("Time / s")
    plt.ylabel("Frequency / Hz")
    plt.title("Spectrogram of Recorded Signal")
    plt.colorbar(label="Power / dB")
    plt.show()

# match filter

import numpy as np
from scipy.signal import chirp, correlate, correlation_lags

def make_up_chirp_ref(fs=48000, T_chirp=1.0, f0=500, f1=22000, alpha=0.1, method="linear"):
    t = np.arange(int(T_chirp * fs)) / fs

    up_ref = chirp(
        t,
        f0=f0,
        f1=f1,
        t1=T_chirp,
        method=method
    )

    window = tukey(len(t), alpha=alpha)
    up_ref = up_ref * window

    # remove DC
    up_ref = up_ref - np.mean(up_ref)

    # energy normalize
    up_ref = up_ref / (np.linalg.norm(up_ref) + 1e-12)

    return up_ref

def match_filter_chirp(rx, up_ref):

    rx_centered = rx - np.mean(rx)
    corr = correlate(rx_centered, up_ref, mode="full", method="fft")
    lags = correlation_lags(len(rx_centered), len(up_ref), mode="full")

    return corr, lags

from scipy.signal import find_peaks
import numpy as np
def analyze_matched_filter_peaks(corr, lags, fs, threshold=0.4, min_distance_ms=0.5):
    corr_abs = np.abs(corr)

    # normalize
    corr_norm = corr_abs / (np.max(corr_abs) + 1e-12)

    # find local peaks above threshold
    threshold = threshold   # 可以试 0.3, 0.4, 0.5
    peaks, props = find_peaks(
        corr_norm,
        height=threshold,
        distance=int(min_distance_ms * 0.001 * fs)   # peaks at least min_distance_ms apart
    )

    peak_lags = lags[peaks]
    peak_heights = props["peak_heights"]

    # only keep positive lags
    valid = peak_lags >= 0
    peak_lags = peak_lags[valid]
    peak_heights = peak_heights[valid]
    return peak_lags, peak_heights

# %%
fs=48000
T_chirp=1.0
f0=500
f1=22000
up_ref = generate_chirp(fs, T_chirp, f0, f1, amp=0.5)
fs_rx, rx = read_recorded_signal("chirp_test_rx.wav")
# Out:
# Saved chirp_test_all_freq_tx.wav
# Duration: 3.0 seconds

# %%
plot_recorded_signal(rx, fs_rx)

# %%
spectrogram_analysis_no_smoothing(rx, fs_rx)

# %%
up_ref = make_up_chirp_ref(fs=48000, T_chirp=1.0, f0=500, f1=22000, alpha=0.1, method="linear")
corr, lags = match_filter_chirp(rx, fs_rx, up_ref)

peak_idx = np.argmax(np.abs(corr))
peak_idx_2nd = np.argsort(np.abs(corr))[-2]
peak_lag_2nd = lags[peak_idx_2nd]
peak_lag = lags[peak_idx]

print("Detected chirp start:", peak_lag)
print("Detected chirp start time:", peak_lag / fs)
print("2nd strongest peak lag:", peak_lag_2nd)
print("2nd strongest peak time:", peak_lag_2nd / fs)
# Out:
# Detected chirp start: 102054
# Detected chirp start time: 2.126125
# 2nd strongest peak lag: 102025
# 2nd strongest peak time: 2.1255208333333333

# %%
# =========================
# 4. Plot matched filter output
# =========================

time_lags = lags / fs

plt.figure(figsize=(12, 4))
plt.plot(time_lags, np.abs(corr))
plt.axvline(peak_lag / fs, color="r", linestyle="--", label="Detected up-chirp")
plt.axvline(peak_lag_2nd / fs, color="g", linestyle="--", label="2nd strongest peak")
plt.xlim(peak_lag / fs - 0.02, peak_lag / fs + 0.07)
plt.xlabel("Lag / time shift (s)")
plt.ylabel("Matched filter magnitude")
plt.title("Up-chirp matched filter output")
plt.legend()
plt.grid(True)
plt.show()

# %%
peak_lags, peak_heights = analyze_matched_filter_peaks(corr, lags, fs_rx, threshold=0.15, min_distance_ms=0.5)
# earliest significant peak
first_peak_lag = peak_lags[0]

# strongest peak
strongest_peak_lag = peak_lags[np.argmax(peak_heights)]

print("Earliest significant peak:", first_peak_lag, first_peak_lag / fs, "s")
print("Strongest peak:", strongest_peak_lag, strongest_peak_lag / fs, "s")
# Out:
# Earliest significant peak: 102025 2.1255208333333333 s
# Strongest peak: 102054 2.126125 s

# %% [markdown]
# #### Need to find earliest reliable peak
# There are two relatively similar magnitude peaks, 29 samples apart. Hence, when doing chirp and synchronisation, we need to make sure we not just detect max peak and set as out starting point. In this case, largest peak is later one and highly likely is due to echo and first one is due to direct path. In this case, we can set threshould and find ealiest reliable peak not simply largest peak

# %%
# plot received signal and detected region

start_sample = first_peak_lag
end_sample = start_sample + len(up_ref)
time_rx = np.arange(len(rx)) / fs

plt.figure(figsize=(12, 4))
plt.plot(time_rx, rx)
plt.axvline(start_sample / fs, color="r", linestyle="--", label="Detected start")
plt.axvline(end_sample / fs, color="g", linestyle="--", label="Detected end")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Received signal with detected up-chirp position")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def one_sided_amplitude_spectrum_no_window(x, fs):
    """
    One-sided amplitude spectrum using raw FFT.
    No Hann / Tukey / Hamming window is applied.
    """
    x = np.asarray(x, dtype=np.float64)

    # remove DC offset
    x = x - np.mean(x)

    N = len(x)

    X = np.fft.rfft(x)
    freqs = np.fft.rfftfreq(N, d=1/fs)

    # amplitude spectrum
    amp = np.abs(X) / N

    # one-sided amplitude correction
    if N % 2 == 0:
        amp[1:-1] *= 2
    else:
        amp[1:] *= 2

    return freqs, amp


# =========================
# 1. Cut received chirp
# =========================

rx_chirp = rx[start_sample:end_sample]

N = len(rx_chirp)


# =========================
# 2. Cut background noise
# =========================
# Use a noise-only region before chirp.
# Make it the same length as the chirp if possible.

noise_end = max(0, start_sample - int(0.1 * fs))
noise_start = max(0, noise_end - N)

rx_noise = rx[noise_start:noise_end]

# If noise segment is shorter than chirp, trim chirp to same length
M = min(len(rx_chirp), len(rx_noise))
rx_chirp = rx_chirp[:M]
rx_noise = rx_noise[:M]


# =========================
# 3. Compute amplitude spectra
# =========================

f_chirp, A_chirp = one_sided_amplitude_spectrum_no_window(rx_chirp, fs)
f_noise, A_noise = one_sided_amplitude_spectrum_no_window(rx_noise, fs)


# =========================
# 4. Relative amplitude over background noise
# =========================

eps = 1e-12

relative_amp_db = 20 * np.log10((A_chirp + eps) / (A_noise + eps))


# =========================
# 5. Plot
# =========================

plt.figure(figsize=(12, 5))
plt.plot(f_chirp, 20 * np.log10(A_chirp + eps), label="Received chirp amplitude")
plt.plot(f_noise, 20 * np.log10(A_noise + eps), label="Background noise amplitude")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude (dB)")
plt.title("Amplitude spectrum: received chirp vs background noise")
plt.grid(True)
plt.legend()
plt.xlim(0, fs / 2)
plt.show()


plt.figure(figsize=(12, 5))
plt.plot(f_chirp, relative_amp_db)
plt.axhline(0, linestyle="--", label="same as background noise")
plt.axhline(10, linestyle="--", label="+10 dB")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Relative amplitude over noise (dB)")
plt.title("Relative received amplitude compared with background noise")
plt.grid(True)
plt.legend()
plt.xlim(0, fs / 2)
plt.show()

# %% [markdown]
# ### Test on linear chirp with useful frequency range from 2kHz to 16kHz

# %%
gen_up_chirp = generate_chirp(fs=48000, T_chirp=1.0, f0=2000, f1=16000, method="linear", filename="chirp_test_linear_freq_tx.wav")
# Out:
# Saved chirp_test_linear_freq_tx.wav
# Duration: 3.0 seconds

# %%
record_chirp_response(fs_rx=48000, record_seconds=5.0, filename="chirp_test_linear_freq_rx.wav")

# %%
rx, fs_rx = record_chirp_response(fs_rx=48000, record_seconds=5.0, filename="chirp_test_log_freq_rx.wav")
plot_recorded_signal(rx, fs_rx)
spectrogram_analysis_no_smoothing(rx, fs_rx)
spectrogram_analysis(rx, fs_rx)

# %%
up_ref = make_up_chirp_ref(fs=48000, T_chirp=1.0, f0=2000, f1=16000, method="linear")
corr, lags = match_filter_chirp(rx, up_ref)

# %% [markdown]
# ### Test on log chirp

# %%
gen_up_chirp = generate_chirp(fs, T_chirp, f0=2000, f1=16000, amp=0.5, method="log",filename="chirp_test_log_freq_tx.wav")
# Out:
# Saved chirp_test_log_freq_tx.wav
# Duration: 3.0 seconds

# %%
record_chirp_response(fs_rx=48000, record_seconds=5.0, filename="chirp_test_log_freq_rx.wav")

# %%
rx, fs_rx = record_chirp_response(fs_rx=48000, record_seconds=5.0, filename="chirp_test_log_freq_rx.wav")
plot_recorded_signal(rx, fs_rx)
spectrogram_analysis_no_smoothing(rx, fs_rx)
spectrogram_analysis(rx, fs_rx)

# %%
up_ref = make_up_chirp_ref(
    fs=48000,
    T_chirp=1.0,
    f0=2000,
    f1=16000,
    method="log"
)

corr, lags = match_filter_chirp(rx, up_ref)
peak_lags, peak_heights = analyze_matched_filter_peaks(corr, lags, fs_rx, threshold=0.15, min_distance_ms=0.5)

# %% [markdown]
# ### Test on up and down chirp

# %%
fs = 48000
T_chirp = 1.0
f0 = 2000
f1 = 16000
amp = 0.5

t = np.arange(int(T_chirp * fs)) / fs

up_chirp = chirp(t, f0=f0, f1=f1, t1=T_chirp, method="linear")
down_chirp = chirp(t, f0=f1, f1=f0, t1=T_chirp, method="linear")

alpha = 0.1  # fraction of signal used for tapering
window = tukey(len(t), alpha=alpha)

up_chirp = amp * up_chirp * window
down_chirp = amp * down_chirp * window

silence_1s = np.zeros(int(1.0 * fs))
silence_02s = np.zeros(int(0.2 * fs))

tx = np.concatenate([
    silence_1s,
    up_chirp,
    silence_02s,
    down_chirp,
    silence_1s
])

write("chirp_test_dual_tx.wav", fs, tx.astype(np.float32))

print("Saved chirp_test_dual_tx.wav")
print("Duration:", len(tx) / fs, "seconds")
# Out:
# Saved chirp_test_dual_tx.wav
# Duration: 4.2 seconds

# %%
record_chirp_response(fs_rx=48000, record_seconds=5.0, filename="chirp_test_dual_freq_rx.wav")
# Out:
# Recording started.
# Play chirp_test_tx.wav now.
# Recording finished.
# Saved chirp_test_dual_freq_rx.wav
# Max amplitude: 0.17224121
# Duration: 5.0 seconds

# %%
rx, fs_rx = read_recorded_signal("chirp_test_dual_freq_rx.wav")
rx, fs_rx = read_recorded_signal("chirp_test_dual_freq_rx.wav")
spectrogram_analysis_no_smoothing(rx, fs_rx)
spectrogram_analysis(rx, fs_rx)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 2
#       1 rx, fs_rx = read_recorded_signal("chirp_test_dual_freq_rx.wav")
# ----> 2 plot_recorded_signal(rx, fs_rx)
#       3 spectrogram_analysis_no_smoothing(rx, fs_rx)
#       4 spectrogram_analysis(rx, fs_rx)
#
# Cell In[94], line 56, in plot_recorded_signal(rx, fs_rx)
#      55 def plot_recorded_signal(rx, fs_rx):
# ---> 56     time_rx = np.arange(len(rx)) / fs_rx
#      57
#      58     plt.figure(figsize=(12, 4))
#      59     plt.plot(time_rx, rx)
#
# TypeError: object of type 'int' has no len()

# %%
up_ref = make_up_chirp_ref(fs=48000, T_chirp=1.0, f0=2000, f1=16000, method="linear")
down_ref = make_up_chirp_ref(fs=48000, T_chirp=1.0, f0=16000, f1=2000, method="linear")
corr_up, lags_up = match_filter_chirp(rx, up_ref)
corr_down, lags_down = match_filter_chirp(rx, down_ref)
